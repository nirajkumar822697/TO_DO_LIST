# %% [markdown]
# # ***`TO-DO LIST`***
#
# - Add Task
# - View
# - Delete
# - change
# - exit

# %%
todo = []

# %%
while True:
    choice = int(input("1.Add Task\n2.View Task\n3.Delete Task\n4.Change Task\n5.Exit Task\n"))

    if choice == 1:
        task = input("Enter Your Task")
        todo.append(task)  # add item in the end of list
        print(f"{task} has been added...")

    elif choice == 2:
        if todo:
            i = 0
            while i < len(todo):
                print(f"Task{i} : {todo[i]}")
                i += 1

        else:
            print("Todo is empty....")

    elif choice == 3:
        if todo:
            task = input("Enter which task you want to remove ?")
            if task in todo:
                index_value = todo.index(task)
                delete_value = todo.pop(index_value)
                print(f"{delete_value} has been removed")

            else:
                print("Task is not available...")
            

        else:
            print("Todo is empty")


    elif choice == 4:
        if todo:
            task = input("Enter your task to modify....")
            if task in todo:
                idx = todo.index(task)
                new_task = input("Enter new task...")
                todo[idx] =new_task
                print("Task modified.....")
                

            else:
                print("Task is not avialable")

        else:
            print("Todo is empty")
        
            






    elif choice == 5:
        print("Exit from Todo list..")
        break
# Out:
# 1.Add Task
# 2.View Task
# 3.Delete Task
# 4.Change Task
# 5.Exit Task
#  1
# Enter Your Task study
# study has been added...
# 1.Add Task
# 2.View Task
# 3.Delete Task
# 4.Change Task
# 5.Exit Task
#  1
# Enter Your Task tea
# tea has been added...
# 1.Add Task
# 2.View Task
# 3.Delete Task
# 4.Change Task
# 5.Exit Task
#  2
# Task0 : study
# Task1 : tea
# 1.Add Task
# 2.View Task
# 3.Delete Task
# 4.Change Task
# 5.Exit Task
#  3
# Enter which task you want to remove ? tea
# tea has been removed
# 1.Add Task
# 2.View Task
# 3.Delete Task
# 4.Change Task
# 5.Exit Task
#  1
# Enter Your Task coding
# coding has been added...
# 1.Add Task
# 2.View Task
# 3.Delete Task
# 4.Change Task
# 5.Exit Task
#  4
# Enter your task to modify.... coding
# Enter new task... coding in python
# Task modified.....
# 1.Add Task
# 2.View Task
# 3.Delete Task
# 4.Change Task
# 5.Exit Task
#  2
# Task0 : study
# Task1 : coding in python
# 1.Add Task
# 2.View Task
# 3.Delete Task
# 4.Change Task
# 5.Exit Task
#  5
# Exit from Todo list..
